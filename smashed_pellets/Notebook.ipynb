# %%
import matplotlib.pyplot as plt

# Pellet labels and values
pellets = ['Pellet 1', 'Pellet 2', 'Pellet 3', 'Pellet 4']
porosity = [0.084799263700668, 0.102394865279403, 0.101798443357254, 0.097194986825362]
errors = [0.0095, 0.0193, 0.0154, 0.0129]

# Create bar plot with error bars
plt.bar(pellets, values, yerr=errors, color='blue', capsize=5)

# Add labels and title
plt.xlabel('Pellets')
plt.ylabel('Porosity')
plt.title('Porosity of Different Pellets with Errors')
# Out:
# Text(0.5, 1.0, 'Porosity of Different Pellets with Errors')
