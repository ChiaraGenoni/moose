# %%
# Fascio di Curve

# %%
import matplotlib as mpl
import math
import numpy as np #library to import csv data
import matplotlib.pyplot as plt #library for visualization
import pylab
import pandas as pd


data20 = pd.read_csv('experimental_data.csv')
data0 = pd.read_csv('stocastich_tools_out_runner00.csv')
data1 = pd.read_csv('stocastich_tools_out_runner01.csv')
data2 = pd.read_csv('stocastich_tools_out_runner02.csv')
data3 = pd.read_csv('stocastich_tools_out_runner03.csv')
data4 = pd.read_csv('stocastich_tools_out_runner04.csv')
data5 = pd.read_csv('stocastich_tools_out_runner05.csv')
data6 = pd.read_csv('stocastich_tools_out_runner06.csv')
data7 = pd.read_csv('stocastich_tools_out_runner07.csv')
data8 = pd.read_csv('stocastich_tools_out_runner08.csv')
data9 = pd.read_csv('stocastich_tools_out_runner09.csv')
data10 = pd.read_csv('stocastich_tools_out_runner10.csv')
data11 = pd.read_csv('stocastich_tools_out_runner11.csv')


# plt.plot(data0['time'], data0['inlet-p'], '.', color = 'C1', label = '1.06789E-12')
# plt.plot(data1['time'], data1['inlet-p'], '.', color = 'C2', label = '7.63503E-13')
# plt.plot(data2['time'], data2['inlet-p'], '.', color = 'C3', label = '5.29349E-13')
# plt.plot(data3['time'], data3['inlet-p'], '.', color = 'C4', label = '3.75621E-13')
# plt.plot(data4['time'], data4['inlet-p'], '.', color = 'C5', label = '2.41577E-13')
# plt.plot(data5['time'], data5['inlet-p'], '.', color = 'C6', label = '9.09582E-14')
# plt.plot(data6['time'], data6['inlet-p'], '.', color = 'C7', label = '4.77189E-14')
# plt.plot(data7['time'], data7['inlet-p'], '.', color = 'C8', label = '2.30126E-14')
plt.plot(data8['time'], data8['inlet-p'], '.', color = 'C9', label = '9.42596E-15')
plt.plot(data9['time'], data9['inlet-p'], '.', color = 'C10', label = '6.18437E-15')
plt.plot(data10['time'], data10['inlet-p'], '.', color = 'C11', label = '4.36658E-15')
plt.plot(data11['time'], data11['inlet-p'], '.', color = 'C12', label = '2.98243E-15')
plt.plot(data20['time'], data20['4_48MPa'], 'v', color='k', label = 'experimental results')
plt.xlabel('time (s)')
plt.xlim(0,300)
plt.ylim(0, 5000000)
plt.ylabel('pressure (Pa)')
plt.legend(title = 'permeability (m\u00B2)')
plt.grid()
